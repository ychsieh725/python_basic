# %% [markdown]
# |型態| 創建方式 | 可不可變 | 有序/無序 |
# |:---:|:---:|:---:|:---:|
# |string|name = "David"|X|V|
# |list|nums = [1, 2, 3,]|V|V|
# |dict| | | |
# |tuple|nums = (1, 2, 3)or1, 2, 3|X| |
# |set|= {1, 2, 3}| |X|

# %%
#字串可以直接相加
data1 = "good"
data2 = "morning"
msg = data1 + " " + data2
print(msg)
# Out:
# good morning

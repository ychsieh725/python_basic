# %% [markdown]
# ##字串格式化

# %% [markdown]
# |語法|說明|
# |:---:|:---:|
# |%s |插入 字串 的值到字串中|
# |%f |插入 浮點數 的值到字串中|
# |%d |插入 整數 的值到字串中|
# |%% |輸出 百分比 (類似跳脫字元)|

# %%
# 多組文字
data1 = "Hello"
data2 = "World"

msg = "%s, %s!" % (data1, data2)
print(msg)
# Out:
# Hello, World!

# %%
# 整數
age = 30
msg = "I'm %d years old." % (age)
print(msg)
# Out:
# I'm 30 years old.

# %%
# 文字與整數
name = "Alex"
age = 30
msg = "%s is %d years old." % (name, age)
print(msg)
# Out:
# Alex is 30 years old.

# %%
# 指定寬度 (維持 10 個字元長度，預設向右看齊)
msg = "|%10s]" % "hello"
print(msg)
# Out:
# |     hello]

# %%
# 文字放在框裡
data = "|%-10s|" % "Hello"
print("ˍ"*12)
print(data)
print("¯"*12)
# Out:
# ˍˍˍˍˍˍˍˍˍˍˍˍ
# |Hello     |
# ¯¯¯¯¯¯¯¯¯¯¯¯

# %%
# 靠左對齊 (維持 10 個字元長度，向左對齊)
msg = "|%-10s]" % "hello" #多一個負號
print(msg)
# Out:
# |hello     ]

# %%
# 指定浮點數位數
data = "|%.2f|" % 3.1415926 #字串長度
print(data)
# Out:
# |3.14|

# %%
# 指定文字長度上限 (只有文字，才在格式化字串中加入「.」來限定字串長度)
msg = "|%.3s]" % "hello" #字元長度
print(msg)
# Out:
# |hel]

# %%
# 空白補 0
data = 3.1415926
msg = "%011f" % data
print(msg)
# Out:
# 0003.141593

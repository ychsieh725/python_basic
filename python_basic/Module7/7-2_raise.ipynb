# %%
# 自訂例外處理
x = -1

if not x > 0:
    raise ValueError("x 要大於 0")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 5
#       1 # 自訂例外處理
#       2 x = -1
#       3
#       4 if not x > 0:
# ----> 5     raise ValueError("x 要大於 0")
#
# ValueError: x 要大於 0

# %%
# 自訂型別錯誤(TypeError)的例外處理
file = "xxx.PDF"
print(file[-3:])
if file[-3:].lower() != "pdf": # 一律轉成小寫
    raise TypeError("附檔名有誤，一定要是 .pdf 或 .PDF")
# Out:
# PDF

# %% [markdown]
# ##### 設計 raise 陳述

# %% [markdown]
# 百貨公司周年慶 消費金額超過 2000 要折 200，滿 4000 折 400 ，以此類推。
#
# 請撰寫一支程式
# 計算客戶消費的結帳金額

# %%
total = 4200
discountnum = total//2000
discount = discountnum*200
print(total-discount)
# Out:
# 3800

# %% [markdown]
# 老師解法

# %%
total = 4200
if total >= 2000:
    total -= 200*(total//2000)
print(total)
# Out:
# 3800
